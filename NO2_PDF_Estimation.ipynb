# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.optimize import curve_fit

# %%
df=pd.read_csv("data.csv", encoding='latin1')
# Out:
# /tmp/ipython-input-1170420938.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("data.csv", encoding='latin1')

# %%
x=df['no2'].dropna().values

# %%
r=102313059
ar=0.05*(r%7)
br=0.3*((r%5)+1)
z=x+ar*np.sin(br*x)

mean=np.mean(z)
variance=np.var(z)
lambda1=1/(2*variance)
c=np.sqrt(lambda1/np.pi)

print("Estimated Parameters:")
print("mean=", mean)
print("lambda=", lambda1)
print("c=", c)
# Out:
# Estimated Parameters:
# mean= 25.812999155899675
# lambda= 0.001460976048430844
# c= 0.02156485844361762
